# %%
#Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pprint as pprint

# %%
#Import CSVS
draft_data_csv = "C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\Draft Results 1987-2015 Split MAIN.csv"
QB_combine_historical_csv = "C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\QB Combine Data 1987.csv"
WR_combine_historical_csv = "C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\WR Combine Data 1987.csv"
combine_2019_csv = "C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\NFL Combine Data 2019.csv"
Top_25_QB_csv = "C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\QB_Combine.csv"
Top_25_WR_csv = "C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\WR_Combine.csv"

# %%
#read csvs
draft_data = pd.read_csv(draft_data_csv)
QB_combine_hist = pd.read_csv(QB_combine_historical_csv)
WR_combine_hist = pd.read_csv(WR_combine_historical_csv)
combine_2019 = pd.read_csv(combine_2019_csv)
Top_25_QB = pd.read_csv(Top_25_QB_csv)
Top_25_WR = pd.read_csv(Top_25_WR_csv)

# %%
#Merge Top 25 QB With Combine Data
Top_25QB_combine_df = pd.merge(Top_25_QB, QB_combine_hist, how="left", on="Player")
#display
Top_25QB_combine_df
# Out:
#     Player_Id  Year_x   Rnd  Pick   Tm              Player Position  \
# 0    NewtCa00    2011   1.0     1  CAR          Cam Newton       QB
# 1    MannPe00    1998   1.0     1  IND      Peyton Manning       QB
# 2    RyanMa00    2008   1.0     3  ATL           Matt Ryan       QB
# 3    WilsRu00    2012   3.0    75  SEA      Russell Wilson       QB
# 4    CulpDa00    1999   1.0    11  MIN    Daunte Culpepper       QB
# 5    BrooAa00    1999   4.0   131  GNB        Aaron Brooks       QB
# 6    DaltAn00    2011   2.0    35  CIN         Andy Dalton       QB
# 7    FlacJo00    2008   1.0    18  BAL          Joe Flacco       QB
# 8    FavrBr00    1991   2.0    33  ATL     Brett Favre HOF       QB
# 9    RoetBe00    2004   1.0    11  PIT  Ben Roethlisberger       QB
# 10   McNaDo00    1999   1.0     2  PHI      Donovan McNabb       QB
# 11   PalmCa00    2003   1.0     1  CIN       Carson Palmer       QB
# 12   RypiMa00    1986   6.0   146  WAS         Mark Rypien       QB
# ...

# %%
#Merge Top 25 WR Draft Results with Combine Data
Top_25WR_combine_df = pd.merge(Top_25_WR, WR_combine_hist, how="left", on="Player")
#display
Top_25WR_combine_df
# Out:
#      Player_Id  Year_x   Rnd  Pick   Tm               Player Pos  \
# 0     MossRa00    1998   1.0    21  MIN           Randy Moss  WR
# 1     HoltTo00    1999   1.0     6  STL           Torry Holt  WR
# 2     RiceJe00    1985   1.0    16  SFO       Jerry Rice HOF  WR
# 3     HarrMa00    1996   1.0    19  IND  Marvin Harrison HOF  WR
# 4     JoneJu02    2011   1.0     6  ATL          Julio Jones  WR
# 5     JohnCh01    2001   2.0    36  CIN         Chad Johnson  WR
# 6     BryaDe01    2010   1.0    24  DAL           Dez Bryant  WR
# 7     MoorHe00    1991   1.0    10  DET         Herman Moore  WR
# 8     RisoAn00    1989   1.0    22  IND          Andre Rison  WR
# 9     SharSt00    1988   1.0     7  GNB      Sterling Sharpe  WR
# 10    BrowEd00    1985   1.0    13  CIN          Eddie Brown  WR
# 11    FitzLa00    2004   1.0     3  ARI     Larry Fitzgerald  WR
# 12    JohnKe00    1996   1.0     1  NYJ     Keyshawn Johnson  WR
# ...

# %%
#save csvs
Top_25WR_combine_df.to_csv("C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\Top25WRCombined2.csv")
Top_25QB_combine_df.to_csv("C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\Top25QBCombined2.csv")
